# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
train_set = pd.read_json('train.json')
train_set.drop(columns=['id'], inplace=True)
train_set.sample(5)
# Out:
#        cuisine                                        ingredients
# 20902  mexican  [tomatoes, fat free milk, all-purpose flour, g...
# 5891   russian  [chopped fresh chives, dry bread crumbs, peppe...
# 25969  chinese  [roasted cashews, cider vinegar, pork tenderlo...
# 35599   indian  [garam masala, cumin seed, ground turmeric, to...
# 7217   british     [milk, beaten eggs, butter, plain flour, salt]

# %%
ing_col = train_set.ingredients.values
all_ings = np.concatenate(tuple(ing_col[i] for i in range(len(ing_col))))
unique_ings, counts = np.unique(all_ings, return_counts=True)
print('number of ingredients in dataset: ', len(all_ings))
print('unique number of ingredients in dataset: ', len(unique_ings))
# Out:
# number of ingredients in dataset:  428275
# unique number of ingredients in dataset:  6714

# %%
ings=pd.DataFrame(all_ings, columns=["Ingredients"])
unique_in=ings.Ingredients.unique()

# %%
count_by_cuisine = train_set.groupby(['cuisine']).count()
count_by_cuisine
# Out:
#               ingredients
# cuisine
# brazilian             467
# british               804
# cajun_creole         1546
# chinese              2673
# filipino              755
# french               2646
# greek                1175
# indian               3003
# irish                 667
# italian              7838
# jamaican              526
# japanese             1423
# korean                830
# mexican              6438
# moroccan              821
# russian               489
# southern_us          4320
# spanish               989
# thai                 1539
# vietnamese            825

# %%
temp=pd.DataFrame(0, index= unique_in, columns= count_by_cuisine.index.values)
temp
# Out:
#                                                     brazilian  british  \
# romaine lettuce                                             0        0
# black olives                                                0        0
# grape tomatoes                                              0        0
# garlic                                                      0        0
# pepper                                                      0        0
# ...                                                       ...      ...
# Lipton® Iced Tea Brew Family Size Tea Bags                  0        0
# Hidden Valley® Greek Yogurt Original Ranch® Dip...          0        0
# lop chong                                                   0        0
# tomato garlic pasta sauce                                   0        0
# crushed cheese crackers                                     0        0
#
#                                                     cajun_creole  chinese  \
# ...

# %%
k=0
for i in range(len(train_set)):
    for j in range(len(train_set.ingredients[i])):
        temp[train_set["cuisine"][i]][train_set.ingredients[i][j]]=temp[train_set["cuisine"][i]][train_set.ingredients[i][j]]+1
temp
# Out:
#                                                     brazilian  british  \
# romaine lettuce                                             0        0
# black olives                                                0        0
# grape tomatoes                                              0        0
# garlic                                                     82       34
# pepper                                                     56       88
# ...                                                       ...      ...
# Lipton® Iced Tea Brew Family Size Tea Bags                  0        0
# Hidden Valley® Greek Yogurt Original Ranch® Dip...          0        0
# lop chong                                                   0        0
# tomato garlic pasta sauce                                   0        0
# crushed cheese crackers                                     0        0
#
#                                                     cajun_creole  chinese  \
# ...

# %%
max_ing_cuis = temp.values.argsort(axis = 0)

num_cut = 20

max_ing_cuis_reshape = max_ing_cuis[-1*np.arange(num_cut)-1].T
#print(max_ing_cuis_reshape)


    
mpi_cuisine = pd.DataFrame(temp.index[max_ing_cuis_reshape],index = temp.columns)
#print(temp.index[max_ing_cuis])
display(mpi_cuisine)

for i in np.arange(len(temp.columns)):
    print("The ",num_cut,"most popular ingredients in ",temp.columns[i],"cuisine are: ", temp.index.values[max_ing_cuis_reshape[i]])
    print("****")
# Out:
# C:\Users\krbon\AppData\Local\Temp/ipykernel_31672/3019073679.py:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   mpi_cuisine = pd.DataFrame(temp.index[max_ing_cuis_reshape],index = temp.columns)
#                       0                  1                  2   \
# brazilian           salt             onions          olive oil
# british             salt  all-purpose flour             butter
# cajun_creole        salt             onions             garlic
# chinese        soy sauce         sesame oil               salt
# filipino            salt             garlic              water
# french              salt              sugar  all-purpose flour
# greek               salt          olive oil      dried oregano
# indian              salt             onions       garam masala
# irish               salt  all-purpose flour             butter
# ...
